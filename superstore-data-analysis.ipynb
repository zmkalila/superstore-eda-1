# %% [markdown]
# # Import library

# %%
# import pandas library for data analysis
import pandas as pd

# %% [markdown]
# # Import and show the dataset

# %%
# read csv file and assign it to a variable
# encoding='windows-1252' is written for this particular dataset otherwise error
df = pd.read_csv('sample_superstore.csv', encoding='windows-1252')

df.head() # to display only the first 5 rows of the dataset
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# # Size of dataset
#
# shows (number_of_rows, number_of_column)

# %%
df.shape
# Out:
# (9994, 21)

# %% [markdown]
# # Customizing the display of the dataset
#
# When printing the dataframe, the default number of rows being shown is 10 rows (the first 5 and the last 5 rows).
#
# Thus, we set the min_rows and max_rows to a certain number to display more rows of the table:

# %%
pd.set_option('display.min_rows', 10)
pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', 50)

# %%
df
# Out:
#       Row ID        Order ID Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156  11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156  11/8/2016  11/11/2016    Second Class
# ...      ...             ...        ...         ...             ...
# 9992    9993  CA-2017-121258  2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914   5/4/2017    5/9/2017    Second Class
#
#      Customer ID Customer Name   Segment        Country         City  ...  \
# 0       CG-12520   Claire Gute  Consumer  United States    Henderson  ...
# 1       CG-12520   Claire Gute  Consumer  United States    Henderson  ...
# ...          ...           ...       ...            ...          ...  ...
# 9992    DB-13060   Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9993    CC-12220  Chris Cortes  Consumer  United States  Westminster  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# # Getting general info of each column
#
# Showing information of each column, the number of non-null data and each column's data type.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %% [markdown]
# # Getting statistical info of numerical data
#
# Showing statistical information of the numerical data (the ones with 'int' or 'float' dtype).

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %% [markdown]
# # Getting statistical info of non-numerical data
#
# Showing information about non-numerical data (the ones with 'object' dtype).

# %%
df.describe(include='O') # 'O' means object data type
# Out:
#               Order ID Order Date   Ship Date       Ship Mode Customer ID  \
# count             9994       9994        9994            9994        9994
# unique            5009       1237        1334               4         793
# top     CA-2017-100111   9/5/2016  12/16/2015  Standard Class    WB-21850
# freq                14         38          35            5968          37
#
#         Customer Name   Segment        Country           City       State  \
# count            9994      9994           9994           9994        9994
# unique            793         3              1            531          49
# top     William Brown  Consumer  United States  New York City  California
# freq               37      5191           9994            915        2001
#
#        Region       Product ID         Category Sub-Category     Product Name
# count    9994             9994             9994         9994             9994
# ...

# %% [markdown]
# <u> Explanation of each row: </u>
# - `count` : to count the number of rows with non-null data for each column
# - `unique` : to count the number of unique value of each column
# - `top` : shows the most frequent data of each column
# - `freq` : shows the frequency of the top data
#
# Thus from the information above, we know some things such as:
# - The highest number of order activities is on 9/5/2016.
# - The most used ship mode is Standard Class with a total of 5968 orders.
# - The name of the customer with most order is William Brown with 37 orders.
# - Office supplies is the most bought product category.
# - etc.

# %% [markdown]
# # Renaming column names

# %% [markdown]
# As you can see above, when I wanted to print the 'Ship Mode' and 'Sub-category' column, it results in error because those column names don't follow the variable-naming rules in Python.
#
# The space ` ` and the hyphen `-` between words has to be replaced with `_`
# thus we have to change the column names:

# %%
df_final = df.rename(columns={'Row ID':'Row_ID',
                   'Order ID':'Order_ID',
                   'Order Date':'Order_Date',
                   'Ship Date':'Ship_Date',
                   'Ship Mode':'Ship_Mode', 
                   'Customer ID':'Customer_ID',
                   'Customer Name':'Customer_Name',
                   'Segment':'Segment', 
                   'Country':'Country',
                   'City':'City',
                   'State':'State',
                   'Postal Code':'Postal_Code',
                   'Region':'Region',
                   'Product ID':'Product_ID',
                   'Category':'Category',
                   'Sub-Category':'Sub_category',
                   'Product Name':'Product_Name',
                   'Sales':'Sales',
                   'Quantity':'Quantity',
                   'Discount':'Discount',
                   'Profit':'Profit'})

# note: some columns such as 'Segment', 'Country', 'City', etc. are still renamed anyways despite having no changes
# just to make sure that I rename them in order and don't leave out any column

df_final
# Out:
#       Row_ID        Order_ID Order_Date   Ship_Date       Ship_Mode  \
# 0          1  CA-2016-152156  11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156  11/8/2016  11/11/2016    Second Class
# ...      ...             ...        ...         ...             ...
# 9992    9993  CA-2017-121258  2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914   5/4/2017    5/9/2017    Second Class
#
#      Customer_ID Customer_Name   Segment        Country         City  ...  \
# 0       CG-12520   Claire Gute  Consumer  United States    Henderson  ...
# 1       CG-12520   Claire Gute  Consumer  United States    Henderson  ...
# ...          ...           ...       ...            ...          ...  ...
# 9992    DB-13060   Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9993    CC-12220  Chris Cortes  Consumer  United States  Westminster  ...
#
#      Postal_Code  Region       Product_ID         Category Sub_category  \
# ...

# %% [markdown]
# <font color='blue'><b>REMEMBER!</b></font>
# I have saved the dataset with all the renamed columns in a new variable called `df_final`.
#
# I did that purposefully to leave the original dataframe just as it is in the `df` variable, and assign the new one in `df_final`.
#
# From now on, we will only modify and "mess" with the `df_final` dataframe.

# %%
df_final[['Ship_Mode']]
# Out:
#            Ship_Mode
# 0       Second Class
# 1       Second Class
# ...              ...
# 9992  Standard Class
# 9993    Second Class
#
# [9994 rows x 1 columns]

# %%
df_final[['Sub_category']]
# Out:
#      Sub_category
# 0       Bookcases
# 1          Chairs
# ...           ...
# 9992        Paper
# 9993   Appliances
#
# [9994 rows x 1 columns]

# %% [markdown]
# Voila! Now the 'Ship_Mode' and 'Sub_category' columns can be printed without errors.

# %% [markdown]
# # Slicing (selecting) columns
#
# There are 2 ways to slice column:
# - `dataframe_name[['column_name']]`
# - `dataframe_name.column_name`
#
# (although from what I've heard, the first one is more preferred and commonly used)

# %% [markdown]
# ## 1 Column

# %%
df_final[['Customer_ID']]
# Out:
#      Customer_ID
# 0       CG-12520
# 1       CG-12520
# 2       DV-13045
# 3       SO-20335
# 4       SO-20335
# 5       BH-11710
# 6       BH-11710
# 7       BH-11710
# 8       BH-11710
# 9       BH-11710
# ...          ...
# 9984    DV-13465
# 9985    DV-13465
# 9986    ML-17410
# 9987    RA-19885
# 9988    RA-19885
# 9989    TB-21400
# 9990    DB-13060
# 9991    DB-13060
# 9992    DB-13060
# 9993    CC-12220
#
# [9994 rows x 1 columns]

# %%
df_final.Customer_ID
# Out:
# 0       CG-12520
# 1       CG-12520
# 2       DV-13045
# 3       SO-20335
# 4       SO-20335
# 5       BH-11710
# 6       BH-11710
# 7       BH-11710
# 8       BH-11710
# 9       BH-11710
#           ...
# 9984    DV-13465
# 9985    DV-13465
# 9986    ML-17410
# 9987    RA-19885
# 9988    RA-19885
# 9989    TB-21400
# 9990    DB-13060
# 9991    DB-13060
# 9992    DB-13060
# 9993    CC-12220
# Name: Customer_ID, Length: 9994, dtype: object

# %% [markdown]
# ## Multiple Columns

# %%
df_final[['Customer_ID', 'Customer_Name', 'Segment']]
# Out:
#      Customer_ID     Customer_Name    Segment
# 0       CG-12520       Claire Gute   Consumer
# 1       CG-12520       Claire Gute   Consumer
# 2       DV-13045   Darrin Van Huff  Corporate
# 3       SO-20335    Sean O'Donnell   Consumer
# 4       SO-20335    Sean O'Donnell   Consumer
# ...          ...               ...        ...
# 9989    TB-21400  Tom Boeckenhauer   Consumer
# 9990    DB-13060       Dave Brooks   Consumer
# 9991    DB-13060       Dave Brooks   Consumer
# 9992    DB-13060       Dave Brooks   Consumer
# 9993    CC-12220      Chris Cortes   Consumer
#
# [9994 rows x 3 columns]

# %% [markdown]
# # Sorting rows

# %%
df_final.sort_values('Sales', ascending=False).head()
# Out:
#       Row_ID        Order_ID  Order_Date   Ship_Date       Ship_Mode  \
# 2697    2698  CA-2014-145317   3/18/2014   3/23/2014  Standard Class
# 6826    6827  CA-2016-118689   10/2/2016   10/9/2016  Standard Class
# 8153    8154  CA-2017-140151   3/23/2017   3/25/2017     First Class
# 2623    2624  CA-2017-127180  10/22/2017  10/24/2017     First Class
# 4190    4191  CA-2017-166709  11/17/2017  11/22/2017  Standard Class
#
#      Customer_ID Customer_Name      Segment        Country           City  \
# 2697    SM-20320   Sean Miller  Home Office  United States   Jacksonville
# 6826    TC-20980  Tamara Chand    Corporate  United States      Lafayette
# 8153    RB-19360  Raymond Buch     Consumer  United States        Seattle
# 2623    TA-21385  Tom Ashbrook  Home Office  United States  New York City
# 4190    HL-15040  Hunter Lopez     Consumer  United States         Newark
#
#       ... Postal_Code   Region       Product_ID    Category Sub_category  \
# ...

# %%
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# Bar Plot is used for visualizing categorical/discrete/object data types.

# %%
plt.figure(figsize=(6,3))
ax = sns.countplot(y='Category',
              data=df_final,
              palette='YlOrBr');

ax.set_title('Sales of each product category',
             fontdict={'fontsize':10,'fontweight':'bold'})

sns.set_style('whitegrid', {'grid.linestyle':'--', 'grid.color':'white'})

# %%
category = df_final['Category'].value_counts()
category.to_frame()
# Out:
#                  count
# Category
# Office Supplies   6026
# Furniture         2121
# Technology        1847

# %%
df_final['Segment'].value_counts().to_frame()
# Out:
#              count
# Segment
# Consumer      5191
# Corporate     3020
# Home Office   1783

# %%
plt.figure(figsize=(6,2))
sns.countplot(y='Segment',
              data=df_final,
              palette='Blues').set_title('Segment of Customers',
                                         fontdict={'fontsize':12,'fontweight':'normal'})

sns.set_style('darkgrid', {'grid.linestyle':'--', 'grid.color':'white'})

# %%
df['Ship Mode'].value_counts().to_frame()
# Out:
#                 count
# Ship Mode
# Standard Class   5968
# Second Class     1945
# First Class      1538
# Same Day          543

# %%
sns.countplot(x='Ship Mode',
              data=df,
              palette='nipy_spectral').set_title('Ship Mode used by Customers');

sns.set_style('darkgrid', {'grid.linestyle':'--', 'grid.color:':'white'})

# %% [markdown]
# ## 'State' column

# %%
df_final['State'].value_counts().sort_values().to_frame()
# Out:
#                       count
# State
# Wyoming                   1
# West Virginia             4
# North Dakota              7
# Maine                     8
# District of Columbia     10
# Vermont                  11
# South Dakota             12
# Montana                  15
# Idaho                    21
# Kansas                   24
# New Hampshire            27
# Iowa                     30
# New Mexico               37
# Nebraska                 38
# Nevada                   39
# South Carolina           42
# Louisiana                42
# Mississippi              53
# Utah                     53
# Rhode Island             56
# Arkansas                 60
# Alabama                  61
# Missouri                 66
# Oklahoma                 66
# Connecticut              82
# Minnesota                89
# Delaware                 96
# Maryland                105
# Wisconsin               110
# Oregon                  124
# New Jersey              130
# Massachusetts           135
# ...

# %%
plt.figure(figsize=(10,4))
plt.xticks(rotation=90)
sns.countplot(x='State',
              data=df,
              palette='magma').set_title('State');
